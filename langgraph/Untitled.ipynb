# %%
import os
import yaml
from dotenv import load_dotenv
from typing import Annotated, TypedDict, Any, List, Literal
from langchain_core.messages import HumanMessage, AnyMessage, AIMessage, SystemMessage
from pydantic import BaseModel, Field
from langchain_groq import ChatGroq

# %%
env_path = r"D:\common_credentials\.env"
load_dotenv(dotenv_path=env_path)
# Out:
# True

# %%
llm= ChatGroq(model='llama-3.1-8b-instant')

# %%
from langchain_community.tools import YouTubeSearchTool
tool = YouTubeSearchTool()

# %%
tool.run("krish naik")
# Out:
# "['https://www.youtube.com/watch?v=4s7mOZ07tBc&pp=ygUKa3Jpc2ggbmFpaw%3D%3D', 'https://www.youtube.com/watch?v=JxgmHe2NyeY&pp=ygUKa3Jpc2ggbmFpaw%3D%3D']"
